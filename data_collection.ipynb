# %%
import pandas as pd

#An empty list to hold individual dataframes from each file
data_list = []

#Columns that are extracted from each file
columns = ['route',
 'name',
 'type',
 'departure_time',
 'arrival_time',
 'duration',
 'price',
 'seats_available',
 'rating']

#List of CSV files to be read
files_list = [
            'JKSRTC_buses.csv',
            'KAAC_buses.csv',
            'West_bengal_buses.csv',
            'NORTH_BENGAL_buses.csv',
            'Bihar_buses.csv',
            'Chandigarh_buses.csv',
            'Assam_buses.csv',
            'Punjab_buses.csv',
            'south_Bengal_buses.csv',
            'Telangana_buses.csv',
            'Kerala_buses.csv',
            'Goa_buses.csv',
            'Andhra_Pradesh_buses.csv']

# Using loop through each file in the files_list
for file in files_list:
    df = pd.read_csv(file)
    df = df[columns]
    data_list.append(df)

#  Concatenate all dataframes in the list into a single dataframe  
file_data = pd.concat(data_list)
file_data = file_data.reset_index(drop = True)
file_data[['from_place', 'to_place']] = file_data['route'].str.split(' to ', expand=True)

# %%
df = pd.DataFrame(file_data)

# Save the DataFrame to a CSV file
df.to_csv("All_Bus_data_Collated.csv", index=False)

print("Data has been saved to All_Bus_data_Collated.csv")
# Out:
# Data has been saved to All_Bus_data_Collated.csv

# %%
data=pd.read_csv("All_Bus_data_Collated.csv")
data
# Out:
#                                          route  \
# 0                  Jammu (j and k) to Srinagar
# 1                  Jammu (j and k) to Srinagar
# 2                  Jammu (j and k) to Srinagar
# 3                  Jammu (j and k) to Srinagar
# 4                  Jammu (j and k) to Srinagar
# ...                                        ...
# 11077  Hyderabad to Anantapur (andhra pradesh)
# 11078  Hyderabad to Anantapur (andhra pradesh)
# 11079  Hyderabad to Anantapur (andhra pradesh)
# 11080  Hyderabad to Anantapur (andhra pradesh)
# 11081  Hyderabad to Anantapur (andhra pradesh)
#
#                                      name  \
# 0                         New Pal Travels
# 1          North Kashmir Tour and Travels
# 2                 Harikesh Tour N Travels
# 3                     Jamna Travels-Jammu
# 4          North Kashmir Tour and Travels
# ...                                   ...
# 11077                  Tranzindia Travels
# 11078                         BTR Travels
# ...

# %%
#function to remove alphabetic characters from a string column

def change_name(x):
    return x.str.replace(r'[A-Za-z]+', '', regex=True)
data['price']=data['price'].transform(change_name)

# %%
#Applying the 'change_name' function to the 'seats_available' column of the DataFrame
data['seats_available']=data['seats_available'].transform(change_name)
data
# Out:
#                                          route  \
# 0                  Jammu (j and k) to Srinagar
# 1                  Jammu (j and k) to Srinagar
# 2                  Jammu (j and k) to Srinagar
# 3                  Jammu (j and k) to Srinagar
# 4                  Jammu (j and k) to Srinagar
# ...                                        ...
# 11077  Hyderabad to Anantapur (andhra pradesh)
# 11078  Hyderabad to Anantapur (andhra pradesh)
# 11079  Hyderabad to Anantapur (andhra pradesh)
# 11080  Hyderabad to Anantapur (andhra pradesh)
# 11081  Hyderabad to Anantapur (andhra pradesh)
#
#                                      name  \
# 0                         New Pal Travels
# 1          North Kashmir Tour and Travels
# 2                 Harikesh Tour N Travels
# 3                     Jamna Travels-Jammu
# 4          North Kashmir Tour and Travels
# ...                                   ...
# 11077                  Tranzindia Travels
# 11078                         BTR Travels
# ...

# %%
#Converting the 'rating' column to numeric values, coercing errors to NaN
data['rating'] = pd.to_numeric(data['rating'], errors='coerce')
data['rating']=data['rating'].fillna(0)
data['rating']=data['rating'].astype('float64')
data
# Out:
#                                          route  \
# 0                  Jammu (j and k) to Srinagar
# 1                  Jammu (j and k) to Srinagar
# 2                  Jammu (j and k) to Srinagar
# 3                  Jammu (j and k) to Srinagar
# 4                  Jammu (j and k) to Srinagar
# ...                                        ...
# 11077  Hyderabad to Anantapur (andhra pradesh)
# 11078  Hyderabad to Anantapur (andhra pradesh)
# 11079  Hyderabad to Anantapur (andhra pradesh)
# 11080  Hyderabad to Anantapur (andhra pradesh)
# 11081  Hyderabad to Anantapur (andhra pradesh)
#
#                                      name  \
# 0                         New Pal Travels
# 1          North Kashmir Tour and Travels
# 2                 Harikesh Tour N Travels
# 3                     Jamna Travels-Jammu
# 4          North Kashmir Tour and Travels
# ...                                   ...
# 11077                  Tranzindia Travels
# 11078                         BTR Travels
# ...

# %%
#Converting the 'seats_available' column to numeric values, coercing errors to NaN
data['seats_available'] = pd.to_numeric(data['seats_available'], errors='coerce')
data['seats_available']=data['seats_available'].fillna(0)
data['seats_available']=data['seats_available'].astype('int64')
data
# Out:
#                                          route  \
# 0                  Jammu (j and k) to Srinagar
# 1                  Jammu (j and k) to Srinagar
# 2                  Jammu (j and k) to Srinagar
# 3                  Jammu (j and k) to Srinagar
# 4                  Jammu (j and k) to Srinagar
# ...                                        ...
# 11077  Hyderabad to Anantapur (andhra pradesh)
# 11078  Hyderabad to Anantapur (andhra pradesh)
# 11079  Hyderabad to Anantapur (andhra pradesh)
# 11080  Hyderabad to Anantapur (andhra pradesh)
# 11081  Hyderabad to Anantapur (andhra pradesh)
#
#                                      name  \
# 0                         New Pal Travels
# 1          North Kashmir Tour and Travels
# 2                 Harikesh Tour N Travels
# 3                     Jamna Travels-Jammu
# 4          North Kashmir Tour and Travels
# ...                                   ...
# 11077                  Tranzindia Travels
# 11078                         BTR Travels
# ...

# %%
#Converting the 'price' column to numeric values, coercing errors to NaN
data['price'] = pd.to_numeric(data['price'], errors='coerce')
data['price']=data['price'].fillna(0)
data['price']=data['price'].astype('int64')
data
# Out:
#                                          route  \
# 0                  Jammu (j and k) to Srinagar
# 1                  Jammu (j and k) to Srinagar
# 2                  Jammu (j and k) to Srinagar
# 3                  Jammu (j and k) to Srinagar
# 4                  Jammu (j and k) to Srinagar
# ...                                        ...
# 11077  Hyderabad to Anantapur (andhra pradesh)
# 11078  Hyderabad to Anantapur (andhra pradesh)
# 11079  Hyderabad to Anantapur (andhra pradesh)
# 11080  Hyderabad to Anantapur (andhra pradesh)
# 11081  Hyderabad to Anantapur (andhra pradesh)
#
#                                      name  \
# 0                         New Pal Travels
# 1          North Kashmir Tour and Travels
# 2                 Harikesh Tour N Travels
# 3                     Jamna Travels-Jammu
# 4          North Kashmir Tour and Travels
# ...                                   ...
# 11077                  Tranzindia Travels
# 11078                         BTR Travels
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11082 entries, 0 to 11081
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   route            11082 non-null  object
#  1   name             11081 non-null  object
#  2   type             11082 non-null  object
#  3   departure_time   11081 non-null  object
#  4   arrival_time     11081 non-null  object
#  5   duration         11081 non-null  object
#  6   price            11082 non-null  int64
#  7   seats_available  11082 non-null  int64
#  8   rating           11082 non-null  float64
#  9   from_place       11082 non-null  object
#  10  to_place         11082 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 952.5+ KB

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sqlalchemy
# Out:
# ...
#
# ...

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

host = "localhost"
port = "3306"
username = "root"
password = "9600578719"
database = "redbus"

engine_string = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
engine = create_engine(engine_string)

table_name = "bus_data"


df=pd.DataFrame(data)
df.to_sql(table_name, engine,index=False)
print("success")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 18
#      14 table_name = "bus_data"
#      17 df=pd.DataFrame(data)
# ---> 18 df.to_sql(table_name, engine,index=False)
#      19 print("success")
#
# File c:\Users\Vijay\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv("All_Bus_data_Collection.csv", index=False)

print("Data has been saved to All_Bus_data_Collection.csv")
# Out:
# Data has been saved to All_Bus_data_Collection.csv

# %%
data
# Out:
#                                          route  \
# 0                  Jammu (j and k) to Srinagar
# 1                  Jammu (j and k) to Srinagar
# 2                  Jammu (j and k) to Srinagar
# 3                  Jammu (j and k) to Srinagar
# 4                  Jammu (j and k) to Srinagar
# ...                                        ...
# 11077  Hyderabad to Anantapur (andhra pradesh)
# 11078  Hyderabad to Anantapur (andhra pradesh)
# 11079  Hyderabad to Anantapur (andhra pradesh)
# 11080  Hyderabad to Anantapur (andhra pradesh)
# 11081  Hyderabad to Anantapur (andhra pradesh)
#
#                                      name  \
# 0                         New Pal Travels
# 1          North Kashmir Tour and Travels
# 2                 Harikesh Tour N Travels
# 3                     Jamna Travels-Jammu
# 4          North Kashmir Tour and Travels
# ...                                   ...
# 11077                  Tranzindia Travels
# 11078                         BTR Travels
# ...
